# %%
import pyarrow as pa
import pyarrow.fs as fs
import json
import cv2
import numpy as np
import os
from dotenv import load_dotenv
from decord import VideoReader
from decord import cpu
import ray
from typing import Dict, Any

# Load environment variables
load_dotenv()
access_key = os.getenv('access_key')
secret_key = os.getenv('secret_key')
region = os.getenv('region')
namespace = os.getenv('namespace')

# Initialize S3 filesystem with credentials
s3 = fs.S3FileSystem(region=region, access_key=access_key, secret_key=secret_key, endpoint_override=f'https://{namespace}.compat.objectstorage.{region}.oraclecloud.com',)

# Define S3 paths
input_path = 'yt-vtt/RepNetImport/'
output_path = 'yt-vtt/fitclass/'

# List JSON files in the input path
files = s3.get_file_info(fs.FileSelector(input_path))
json_files = [file.path for file in files if file.path.endswith('.json')]

def process_batch(batch:Dict[str, Any]):
            print(batch['video_path'])
            ranges = batch['value'][0]['ranges'][0]
            print(ranges)
            labels = batch['value'][0]['timelinelabels']
            start_frame = ranges['start']
            end_frame = ranges['end']
            vr = batch['video'][0]
            print(vr.shape)
            video_path = batch['video_path'][0]
            fps = batch['fps'][0]
            print(f"Processing video: {video_path}, start: {start_frame}, end: {end_frame}")
            # Create new video segment
            output_file_name = f"{os.path.basename(video_path).split('.')[0]}_{start_frame}_{end_frame}.mp4"
            output_file_path = os.path.join(output_path, output_file_name)

            # Initialize VideoWriter
            frame_width, frame_height = vr[0].shape[1], vr[0].shape[0]
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            temp_file = f"/tmp/{output_file_name}"
            vw = cv2.VideoWriter(temp_file, fourcc, fps, (frame_width, frame_height))

            for frame in vr:
                img = frame
                vw.write(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
            vw.release()
             # Convert the video to H.264 format using ffmpeg
            h264_temp_file = f"/tmp/h264_{output_file_name}"
            os.system(f"ffmpeg -i {temp_file} -c:v libx264 -preset fast -crf 23 -y {h264_temp_file}")

            # Replace the temp_file with the H.264 converted file
            os.remove(temp_file)
            temp_file = h264_temp_file
            
            # Upload video to S3
            with open(temp_file, 'rb') as temp_video:
                with s3.open_output_stream(output_file_path) as output_stream:
                    output_stream.write(temp_video.read())

            os.remove(temp_file)
            print(f"Uploaded video: {output_file_path}")

            # Create JSON metadata
            json_metadata = {
                "data": {
                    "video": f's3://{output_file_path}'
                },
                "annotations": [
                    {
                        "result": [
                            {
                                "type": "number",
                                "value": {
                                    "number": int(labels[0])
                                },
                                "to_name": "video",
                                "from_name": "rep"
                            }
                        ]
                    }
                ]
            }

            # Upload JSON metadata to S3
            json_file_name = f"{os.path.basename(output_file_name).split('.')[0]}.json"
            json_file_path = os.path.join(output_path, json_file_name)
            with s3.open_output_stream(json_file_path) as json_stream:
                json_stream.write(json.dumps(json_metadata).encode('utf-8'))

            print(f"Uploaded JSON: {json_file_path}")
            return batch
            

@ray.remote
def process_file(json_file):
    # Read JSON file
    print(f"Processing file: {json_file}")
    with s3.open_input_file(json_file) as f:
        data = json.load(f)

    # Extract video path
    video_path = data['data']['video'].split('s3://')[1]

    # Read video using decord
    with s3.open_input_file(video_path) as video_file:
        vr = VideoReader(video_file, ctx=cpu(0))
        fps = vr.get_avg_fps()
        
    # Process annotation results using ray.data with map_batches
    results = ray.data.from_items([
        {
            **result,
            "video_path": video_path,
            "fps": fps,
            "video": np.array([vr[frame].asnumpy() for frame in range(result['value']['ranges'][0]['start'], result['value']['ranges'][0]['end'] + 1)])
        }
        for annotation in data['annotations']
        for result in annotation['result']
    ])
    results.filter(lambda x:  int(x['value']['timelinelabels'][0]) > 2).map_batches(process_batch).take_all()

# Initialize Ray
ray.init(ignore_reinit_error=True)

# Process files in parallel
futures = [process_file.remote(json_file) for json_file in json_files]
ray.get(futures)

# Shutdown Ray
ray.shutdown()
# Out:
# 2025-05-07 21:38:04,910	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (process_file pid=28925) Processing file: yt-vtt/RepNetImport/converted_-cAGR3GiZIU.json
# (process_file pid=28921) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28921)   warnings.warn(
# (process_file pid=28921) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28921) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28921) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28930) Processing file: yt-vtt/RepNetImport/converted_1hzqrwvOLn0.json [repeated 15x across cluster]
# (process_file pid=29337) Processing file: yt-vtt/RepNetImport/converted_47_RmzItlJg.json
# (process_file pid=29337) Processing file: yt-vtt/RepNetImport/converted_47_RmzItlJg.json
# (process_file pid=28928) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28928)   warnings.warn(
# (process_file pid=28928) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28928) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28928) Running 0: 0.00 row [00:00, ? row/s]
# (raylet) Spilled 3053 MiB, 96 objects, write throughput 618 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (pid=28915) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28915) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28915)   warnings.warn(
# (process_file pid=28915) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28915) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (raylet) Spilled 4623 MiB, 143 objects, write throughput 524 MiB/s.
# (raylet) Spilled 4623 MiB, 143 objects, write throughput 524 MiB/s.
# (process_file pid=28929) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28929)   warnings.warn(
# (process_file pid=28929) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28929) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28929) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28929)   warnings.warn(
# (process_file pid=28929) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28929) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28929) Running 0: 0.00 row [00:00, ? row/s]
# (pid=28926) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28926) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28926)   warnings.warn(
# (process_file pid=28926) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28926) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (raylet) Spilled 8339 MiB, 237 objects, write throughput 558 MiB/s.
# (raylet) Spilled 8339 MiB, 237 objects, write throughput 558 MiB/s.
# (process_file pid=28917) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28917)   warnings.warn(
# (process_file pid=28917) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28917) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28917) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28917)   warnings.warn(
# (process_file pid=28917) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28917) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28917) Running 0: 0.00 row [00:00, ? row/s]
# (pid=28918) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28924) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters. [repeated 2x across cluster]
# (process_file pid=28924)   warnings.warn( [repeated 2x across cluster]
# (process_file pid=28924) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data [repeated 2x across cluster]
# (process_file pid=28924) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)] [repeated 2x across cluster]
# (pid=28924) Running 0: 0.00 row [00:00, ? row/s]
# (pid=28927) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28927) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28927)   warnings.warn(
# (process_file pid=28927) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28927) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (raylet) Spilled 16745 MiB, 495 objects, write throughput 598 MiB/s.
# (raylet) Spilled 16745 MiB, 495 objects, write throughput 598 MiB/s.
# (process_file pid=28922) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28922)   warnings.warn(
# (process_file pid=28922) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28922) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28922) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28922)   warnings.warn(
# (process_file pid=28922) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28922) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28922) Running 0: 0.00 row [00:00, ? row/s]
# (pid=28920) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28920) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28920)   warnings.warn(
# (process_file pid=28920) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28920) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28923) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28923) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28923)   warnings.warn(
# (process_file pid=28923) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28923) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28925) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28925) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28925)   warnings.warn(
# (process_file pid=28925) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28925) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28916) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28916)   warnings.warn(
# (process_file pid=28916) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28916)   warnings.warn(
# (pid=28916) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28916) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28916) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28919) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=28919) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28919)   warnings.warn(
# (process_file pid=28919) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28919) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28930) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28930)   warnings.warn(
# (process_file pid=28930) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28930) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (process_file pid=28930) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=28930)   warnings.warn(
# (process_file pid=28930) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=28930) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=28930) Running 0: 0.00 row [00:00, ? row/s]
# (process_file pid=29337) /Users/kanantharaman/anaconda3/lib/python3.11/site-packages/ray/data/dataset.py:1331: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
# (process_file pid=29337)   warnings.warn(
# (process_file pid=29337) Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-07_21-38-00_036548_89962/logs/ray-data
# (process_file pid=29337) Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[Filter(<lambda>)->MapBatches(process_batch)]
# (pid=29337) Running 0: 0.00 row [00:00, ? row/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 137
#     135 # Process files in parallel
#     136 futures = [process_file.remote(json_file) for json_file in json_files]
# --> 137 ray.get(futures)
#     139 # Shutdown Ray
#     140 ray.shutdown()
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:2782, in get(object_refs, timeout)
#    2776     raise ValueError(
#    2777         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2778         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2779     )
#    2781 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2782 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2783 for i, value in enumerate(values):
#    2784     if isinstance(value, RayError):
#
# File ~/anaconda3/lib/python3.11/site-packages/ray/_private/worker.py:903, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     893         raise TypeError(
#     894             f"Attempting to call `get` on the value {object_ref}, "
#     895             "which is not an ray.ObjectRef."
#     896         )
#     898 timeout_ms = (
#     899     int(timeout * 1000) if timeout is not None and timeout != -1 else -1
#     900 )
#     901 data_metadata_pairs: List[
#     902     Tuple[ray._raylet.Buffer, bytes]
# --> 903 ] = self.core_worker.get_objects(
#     904     object_refs,
#     905     timeout_ms,
#     906 )
#     908 debugger_breakpoint = b""
#     909 for data, metadata in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:3211, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/includes/common.pxi:83, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
ray.shutdown()

# %%
vr = VideoReader(video_path, ctx=cpu(0))
fps = vr.get_avg_fps()
print(f"FPS: {fps}")

# %%
# !python3 ../drivers/ray_pipeline_splitworkouts.py
# Out:
# 2025-05-09 16:17:54,680	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# Processing file: yt-vtt/RepNetImport/converted_23P40lccIsY.json
# Processing file: yt-vtt/RepNetImport/converted_23P40lccIsY.json
# 2025-05-09 16:18:09,387	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:09,387	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]2025-05-09 16:18:09,387	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:09,387	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
#
# ✔️  Dataset execution finished in 0.04 seconds: : 0.00 row [00:00, ? row/s]
#
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# Processing file: yt-vtt/RepNetImport/converted_TI4yuhzedm4.json
#
# ✔️  Dataset execution finished in 0.04 seconds: : 0.00 row [00:00, ? row/s]
#
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# Processing file: yt-vtt/RepNetImport/converted_TI4yuhzedm4.json
# 2025-05-09 16:18:13,019	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:13,019	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:13,019	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]2025-05-09 16:18:13,019	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 3; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:01, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:01, ? row/s]e: : 0.00 row [00:01, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 3; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:01, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:01, ? row/s]e: : 0.00 row [00:01, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:02, ? row/s]e: : 0.00 row [00:02, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:02, ? row/s]e: : 0.00 row [00:02, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:03, ? row/s]e: : 0.00 row [00:03, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:03, ? row/s]e: : 0.00 row [00:03, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:04, ? row/s]e: : 0.00 row [00:04, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:04, ? row/s]e: : 0.00 row [00:04, ? row/s]
#
#                                                                                                                 e: : 0.00 row [00:05, ? row/s]
# (MapBatches(process_batch) pid=319) ['yt-vtt/converted_videos/converted_TI4yuhzedm4.mp4']
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) {'end': 2380, 'start': 2125}
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) (256, 144, 256, 3)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) Processing video: yt-vtt/converted_videos/converted_TI4yuhzedm4.mp4, start: 2125, end: 2380
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) ['yt-vtt/converted_videos/converted_TI4yuhzedm4.mp4']
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) {'end': 2380, 'start': 2125}
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) (256, 144, 256, 3)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
#                                                                                                                 e: : 0.00 row [00:06, ? row/s]
# (MapBatches(process_batch) pid=319) Processing video: yt-vtt/converted_videos/converted_TI4yuhzedm4.mp4, start: 2125, end: 2380
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 3; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:06, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]e: : 0.00 row [00:06, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:06, ? row/s]e: : 0.00 row [00:06, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]e: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavutil      59. 39.100 / 59. 39.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavcodec     61. 19.100 / 61. 19.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavformat    61.  7.100 / 61.  7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavdevice    61.  3.100 / 61.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavfilter    10.  4.100 / 10.  4.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libswscale      8.  3.100 /  8.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libswresample   5.  3.100 /  5.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libpostproc    58.  3.100 / 58.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/converted_TI4yuhzedm4_2125_2380.mp4':
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     major_brand     : isom
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     minor_version   : 512
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     compatible_brands: isomiso2mp41
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     encoder         : Lavf61.7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Duration: 00:00:10.67, start: 0.000000, bitrate: 331 kb/s
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 256x144 [SAR 1:1 DAR 16:9], 330 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         handler_name    : VideoHandler
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         vendor_id       : [0][0][0][0]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Stream mapping:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
#
# (MapBatches(process_batch) pid=319) ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavutil      59. 39.100 / 59. 39.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavcodec     61. 19.100 / 61. 19.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavformat    61.  7.100 / 61.  7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavdevice    61.  3.100 / 61.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libavfilter    10.  4.100 / 10.  4.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libswscale      8.  3.100 /  8.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libswresample   5.  3.100 /  5.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   libpostproc    58.  3.100 / 58.  3.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/converted_TI4yuhzedm4_2125_2380.mp4':
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     major_brand     : isom
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     minor_version   : 512
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     compatible_brands: isomiso2mp41
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     encoder         : Lavf61.7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Duration: 00:00:10.67, start: 0.000000, bitrate: 331 kb/s
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 256x144 [SAR 1:1 DAR 16:9], 330 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         handler_name    : VideoHandler
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         vendor_id       : [0][0][0][0]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Stream mapping:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
#                                                                                                                                            (MapBatches(process_batch) pid=319)   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Press [q] to stop, [?] for help
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] using SAR=1/1
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] profile High, level 1.2, 4:2:0, 8-bit
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=4 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Output #0, mp4, to '/tmp/h264_converted_TI4yuhzedm4_2125_2380.mp4':
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     major_brand     : isom
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     minor_version   : 512
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     compatible_brands: isomiso2mp41
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     encoder         : Lavf61.7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x144 [SAR 1:1 DAR 16:9], q=2-31, 24 fps, 12288 tbn (default)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         handler_name    : VideoHandler
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         vendor_id       : [0][0][0][0]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         encoder         : Lavc61.19.100 libx264
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Side data:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 3; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:07, ? row/s](MapBatches(process_batch) pid=319)   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Press [q] to stop, [?] for help
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] using SAR=1/1
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] profile High, level 1.2, 4:2:0, 8-bit
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7fef05007640] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=4 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) Output #0, mp4, to '/tmp/h264_converted_TI4yuhzedm4_2125_2380.mp4':
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     major_brand     : isom
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     minor_version   : 512
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     compatible_brands: isomiso2mp41
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)     encoder         : Lavf61.7.100
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x144 [SAR 1:1 DAR 16:9], q=2-31, 24 fps, 12288 tbn (default)
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Metadata:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         handler_name    : VideoHandler
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         vendor_id       : [0][0][0][0]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         encoder         : Lavc61.19.100 libx264
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)       Side data:
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319)         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
#
#                                                                                                                                            (MapBatches(process_batch) pid=319) [out#0/mp4 @ 0x7fef05006080] video:155KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 2.010041%
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) frame=  256 fps=0.0 q=-1.0 Lsize=     159KiB time=00:00:10.58 bitrate= 122.7kbits/s speed=45.9x
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:07, ? row/s]
#                                                                                                                 e: : 0.00 row [00:07, ? row/s]
# (MapBatches(process_batch) pid=319) [libx264 @ 0x
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] coded y,uvDC,uvAC intra: 96.0% 97.9% 49.6% inter: 11.6% 10.2% 1.0%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] i16 v,h,dc,p:  0%  0%  0% 100%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 14% 20%  6%  5%  8%  5% 11% 11%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 13% 17% 10%  8%  8%  8% 11% 11%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] i8c dc,h,v,p: 49% 19% 18% 14%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] Weighted P-Frames: Y:0.0% UV:0.0%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] ref P L0: 75.7% 24.3%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] ref B L0: 91.2%  8.8%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] ref B L1: 99.6%  0.4%
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) [libx264 @ 0x7f9f9d208a80] kb/s:92.51
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) Uploaded video: yt-vtt/fitclass/converted_TI4yuhzedm4_3322_3513.mp4
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# (MapBatches(process_batch) pid=319) Uploaded video: yt-vtt/fitclass/converted_TI4yuhzedm4_3322_3513.mp4
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 0; Resourc
# Running Dataset. Active & requested resources: 1/16 CPU, 22.5MB/1.0GB object sto
#
# ✔️  Dataset execution finished in 12.69 seconds: 100%|█| 4.00/4.00 [00:12<00:00,
#
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 0; Resourc
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
#
# ✔️  Dataset execution finished in 12.69 seconds: 100%|█| 4.00/4.00 [00:12<00:00,
#
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 0; Resourc
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0
# Processing file: yt-vtt/RepNetImport/converted_TJAnYJDcO68.json
# (MapBatches(process_batch) pid=319) Uploaded JSON: yt-vtt/fitclass/converted_TI4yuhzedm4_3322_3513.json
# Processing file: yt-vtt/RepNetImport/converted_TJAnYJDcO68.json
# (MapBatches(process_batch) pid=319) Uploaded JSON: yt-vtt/fitclass/converted_TI4yuhzedm4_3322_3513.json
# 2025-05-09 16:18:30,084	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:30,084	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]2025-05-09 16:18:30,084	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:30,084	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
#
# ✔️  Dataset execution finished in 0.02 seconds: : 0.00 row [00:00, ? row/s]
#
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# Processing file: yt-vtt/RepNetImport/converted_TPx6GbnyXY4.json
#
# ✔️  Dataset execution finished in 0.02 seconds: : 0.00 row [00:00, ? row/s]
#
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 0.00 row [00:00, ? row/s]
# Processing file: yt-vtt/RepNetImport/converted_TPx6GbnyXY4.json
# 2025-05-09 16:18:40,286	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:40,287	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]2025-05-09 16:18:40,286	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-05-09_16-17-51_130865_99818/logs/ray-data
# 2025-05-09 16:18:40,287	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(process_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch) 1: 0.00 row [00:00, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 13; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:01, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:01, ? row/s]re: : 0.00 row [00:01, ? row/s]
# - MapBatches(process_batch): Tasks: 1 [backpressured]; Queued blocks: 13; Resources: 1.0 CPU, 256.0MB object store: : 0.00 row [00:01, ? row/s]
# Running Dataset. Active & requested resources: 1/16 CPU, 256.0MB/1.0GB object store: : 0.00 row [00:01, ? row/s]re: : 0.00 row [00:01, ? row/s]

# %%
import ray
ray.init(ignore_reinit_error=True)
# Out:
# 2025-05-08 21:04:37,799	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.11.5', ray_version='2.44.1', ray_commit='daca7b2b1a950dc7f731e34e74c76ae383794ffe')

# %%
ray.nodes()[0]
# Out:
# {'NodeID': 'a91b47950e52ed7b184e47cb281f50874b333c62254d014029f00b3e',
#  'Alive': True,
#  'NodeManagerAddress': '127.0.0.1',
#  'NodeManagerHostname': 'ML-kanantharaman',
#  'NodeManagerPort': 60731,
#  'ObjectManagerPort': 60730,
#  'ObjectStoreSocketName': '/tmp/ray/session_2025-05-08_21-04-34_701633_80767/sockets/plasma_store',
#  'RayletSocketName': '/tmp/ray/session_2025-05-08_21-04-34_701633_80767/sockets/raylet',
#  'MetricsExportPort': 64354,
#  'NodeName': '127.0.0.1',
#  'RuntimeEnvAgentPort': 64693,
#  'DeathReason': 0,
#  'DeathReasonMessage': '',
#  'alive': True,
#  'Resources': {'memory': 42373300224.0,
#   'CPU': 16.0,
#   'node:127.0.0.1': 1.0,
#   'object_store_memory': 2147483648.0,
#   'node:__internal_head__': 1.0},
#  'Labels': {'ray.io/node_id': 'a91b47950e52ed7b184e47cb281f50874b333c62254d014029f00b3e'}}

# %%
import pyarrow.fs as fs
import os
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
access_key = os.getenv('access_key')
secret_key = os.getenv('secret_key')
region = os.getenv('region')
namespace = os.getenv('namespace')

# Initialize S3 filesystem with credentials
s3 = fs.S3FileSystem(region=region, access_key=access_key, secret_key=secret_key, endpoint_override=f'https://{namespace}.compat.objectstorage.{region}.oraclecloud.com',)

# %%
s3 = fs.S3FileSystem(region=region, access_key=access_key, secret_key=secret_key, endpoint_override=f'https://{namespace}.compat.objectstorage.{region}.oraclecloud.com',)

# %%
# Define S3 paths
input_path = 'yt-vtt/RepNetImport/'
output_path = 'yt-vtt/fitclass/'

# List JSON files in the input path
files = s3.get_file_info(fs.FileSelector(input_path))
json_files = [file.path for file in files if file.path.endswith('.json')]

# %%
def filter_existing_files(json_files, output_path):
    """
    Filters out JSON files whose corresponding output files already exist in the output path.
    """
    filtered_files = []
    out_files = s3.get_file_info(fs.FileSelector(output_path))
    
    for json_file in json_files:
            videoid = json_file.split('converted_')[1].split('.')[0]
            exists = [file.path for file in out_files if videoid in file.path]
            if(len(exists) == 0):
                filtered_files.append(json_file)
            else:
                print(f"File {json_file} already exists in output path. Skipping.")
    return filtered_files

# %%
len(filter_existing_files(json_files, output_path))
# Out:
# File yt-vtt/RepNetImport/converted_-cAGR3GiZIU.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_-cDGcc8Wc70.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_-jJm9BK3Pcg.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_0NsesOZEU2A.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_0iqP6WP2ET4.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_1ADarF8TSxE.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_1AGiq77wZ9c.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_1M-TtC2loIM.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_1WpDUlJkf5Q.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_1hzqrwvOLn0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_2bfAZ4mcGjo.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_2incNOpRqQ0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_3GiZJlXRX5c.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_3_AX2mToMf0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_3qcNMLjLLOU.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_47_RmzItlJg.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_4EkKhkSNjWY.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_4aYK9qdGvx4.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_4yrae8jGtBA.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_52CsN28jnS0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_5AgitaHMZq4.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_5EKASAhRF7M.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_5WC7X46Qeho.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_5awUOmRp3s0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_6-9TzTYFqyY.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_75DfmpQ5HLo.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_78rlEPxuqsI.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_7R6HRYiRY40.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_7T7E0awt8tM.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_7j-h343eLow.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_84QLkB45g80.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_8kE9ffM1V9o.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_92fq0hCa2PY.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_95hX_OMuIpg.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_9o12yDbfbqA.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_9s9Pz7yMyms.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_A_UVYG5IJ90.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_AtZt2klIDXA.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_B4Mx6t8od5E.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_C839JNdQM14.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_Cf_6ME_Mhds.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_DBQEdYlDe4o.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_DGhHgiCfAb0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_DNPKbHFfjx8.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_DTXLpcOZYCw.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_DqDR2FSBZPM.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_Dujk3eu8MXU.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_ED_sooi1U1w.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_EagY20j2tyw.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_EbO8YD-jpOE.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_FUFQrP47ejo.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_FkNFctqPmis.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_Fy3uNFyDYqU.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_G8RH1mUDF9Q.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_GHw82QWi_BI.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_GJ-kWpMuIRI.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_GsFOq_gBQfI.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_H21MYZsw_2A.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_H7jIW7UAdII.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_HE45jVN7XKM.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_HxznfDcoNtc.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_I1DWwyvmE5I.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_IAHyHwwlBsY.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_IT5_vNMVwF0.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_J3i3oxyNn9M.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_JwQpTP_2rM4.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_KO3NPdBrdDA.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_KTSnlOGoC7E.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_KfNcTgZY3zY.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_Kt-jkKqHKpE.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_LKLoudXjDXc.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted_M0Z5_t2hkZo.json already exists in output path. Skipping.
# File yt-vtt/RepNetImport/converted