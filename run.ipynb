# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys

# %%
from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()
# Out:
# True

# %%
import ray
ray.shutdown()
ray.init()
# Out:
# 2025-08-04 13:40:18,386	WARNING services.py:2152 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2025-08-04 13:40:19,656	INFO worker.py:1908 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.12.11', ray_version='2.47.1', ray_commit='61d3f2f1aa33563faa398105f4abda88cb39440b')
# (ProxyActor pid=2675) INFO 2025-08-04 13:40:44,017 proxy 172.17.0.2 -- Proxy starting on node 5e8f64426f28cfce122a7be1a7787ca8368af29d5ef642aea435ae88 (HTTP port: 8000).
# (ProxyActor pid=2675) INFO 2025-08-04 13:40:44,064 proxy 172.17.0.2 -- Got updated endpoints: {}.
# (ServeController pid=2672) INFO 2025-08-04 13:41:03,646 controller 2672 -- Deploying new version of Deployment(name='ActionDetectorClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 13:41:03,648 controller 2672 -- Deploying new version of Deployment(name='RepCounterClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 13:41:03,650 controller 2672 -- Deploying new version of Deployment(name='Ingress', app='default') (initial target replicas: 1).
# (ProxyActor pid=2675) INFO 2025-08-04 13:41:06,207 proxy 172.17.0.2 -- Got updated endpoints: {Deployment(name='Ingress', app='default'): EndpointInfo(route='/', app_is_cross_language=False)}.
# (ProxyActor pid=2675) INFO 2025-08-04 13:41:06,237 proxy 172.17.0.2 -- Started <ray.serve._private.router.SharedRouterLongPollClient object at 0x7f7cba1b5910>.
# (ServeController pid=2672) INFO 2025-08-04 13:41:06,307 controller 2672 -- Adding 1 replica to Deployment(name='ActionDetectorClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 13:41:06,309 controller 2672 -- Adding 1 replica to Deployment(name='RepCounterClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 13:41:06,311 controller 2672 -- Adding 1 replica to Deployment(name='Ingress', app='default').
# (ServeReplica:default:RepCounterClass pid=2670) /workspaces/visionmlstudio/serve/
# (ServeReplica:default:RepCounterClass pid=2670) Using cache found in /home/jovyan/.cache/torch/hub/huggingface_pytorch-image-models_main
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 13:42:23,969 default_Ingress 1uhu3hy6 e134a6f0-5f8e-4589-afed-2d277bf3a38d -- WS /ws OK 41.8ms
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (1000, '')
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 7 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 8 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 9 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 10 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 11 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 12 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 13 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 14 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 15 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 16 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 17 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 18 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 19 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 20 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 21 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 22 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 23 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 24 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 25 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 26 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 27 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 28 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 29 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 30 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 31 from client
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 13:45:17,036 default_Ingress 1uhu3hy6 dd604f42-c08f-4409-bab5-5f18db913b83 -- WS /ws OK 9042.5ms
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 32 from client
# (ServeReplica:default:Ingress pid=2680) WebSocket error: all input arrays must have the same shape
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 17:29:56,769 default_Ingress 1uhu3hy6 643b8542-6763-460a-9a13-a9443898c2e5 -- WS /ws OK 12118.0ms
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (1000, '')
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 7 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 8 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 9 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 10 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 11 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 12 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 13 from client
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 17:34:11,908 default_Ingress 1uhu3hy6 cb84f413-781a-42ac-9a0c-71480569d8f8 -- WS /ws OK 5333.3ms
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 7 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 8 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 9 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 10 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 11 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 12 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 13 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 14 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 15 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 16 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 17 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 18 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 19 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 20 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 21 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 22 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 23 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 24 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 25 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 26 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 27 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 28 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 29 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 30 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 31 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 32 from client
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 19:29:44,413 default_Ingress 1uhu3hy6 b47f378c-e8e4-4e38-b473-9ec821df1598 -- Started <ray.serve._private.router.SharedRouterLongPollClient object at 0x7f90cd74d100>.
# (ServeReplica:default:ActionDetectorClass pid=2671) /opt/conda/lib/python3.12/site-packages/ray/serve/_private/replica.py:1365: UserWarning: Calling sync method '__call__' directly on the asyncio loop. In a future version, sync methods will be run in a threadpool by default. Ensure your sync methods are thread safe or keep the existing behavior by making them `async def`. Opt into the new behavior by setting RAY_SERVE_RUN_SYNC_IN_THREADPOOL=1.
# (ServeReplica:default:ActionDetectorClass pid=2671)   warnings.warn(
# (ServeReplica:default:ActionDetectorClass pid=2671) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 0 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 1 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 2 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 3 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 4 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 5 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 6 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Selected frame 7 with shape (180, 320, 4)
# (ServeReplica:default:ActionDetectorClass pid=2671) Processing 8 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2671) INFO 2025-08-04 19:30:19,061 default_ActionDetectorClass 8hv13gvb b47f378c-e8e4-4e38-b473-9ec821df1598 -- CALL /ws OK 34519.9ms
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 19:30:19,086 default_Ingress 1uhu3hy6 b47f378c-e8e4-4e38-b473-9ec821df1598 -- WS /ws OK 52041.6ms
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.send', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) Action detection result: {'action': 'class_6'}
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 7 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 8 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 9 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 10 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 11 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 12 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 13 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 14 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 15 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (3686400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 16 from client
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 19:50:25,529 default_Ingress 1uhu3hy6 cb7ecce8-d3ae-4665-aaa2-cdb072b1e1f8 -- WS /ws OK 11668.8ms
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 7 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 8 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 9 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 10 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 11 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 12 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 13 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 14 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 15 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 16 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 17 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 18 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 19 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 20 from client
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 20:08:10,214 default_Ingress 1uhu3hy6 ea4a9154-97fa-4f47-b838-488059f8d8ee -- WS /ws OK 14649.0ms
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 1 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 2 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 3 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 4 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (230400,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 5 from client
# (ServeReplica:default:Ingress pid=2680) Received frame (921600,) from client
# (ServeReplica:default:Ingress pid=2680) Received frame 6 from client
# (ServeReplica:default:Ingress pid=2680) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2680) INFO 2025-08-04 20:13:30,865 default_Ingress 1uhu3hy6 a88e34eb-13d7-40d4-be82-b46a63da8118 -- WS /ws OK 7277.8ms
# (ServeController pid=2672) INFO 2025-08-04 22:33:30,102 controller 2672 -- Deploying new version of Deployment(name='ActionDetectorClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 22:33:30,107 controller 2672 -- Deploying new version of Deployment(name='RepCounterClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 22:33:30,108 controller 2672 -- Deploying new version of Deployment(name='Ingress', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,118 controller 2672 -- Stopping 1 replicas of Deployment(name='ActionDetectorClass', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,118 controller 2672 -- Adding 1 replica to Deployment(name='ActionDetectorClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,129 controller 2672 -- Stopping 1 replicas of Deployment(name='RepCounterClass', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,129 controller 2672 -- Adding 1 replica to Deployment(name='RepCounterClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,145 controller 2672 -- Stopping 1 replicas of Deployment(name='Ingress', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 22:33:35,146 controller 2672 -- Adding 1 replica to Deployment(name='Ingress', app='default').
# (ServeController pid=2672) INFO 2025-08-04 22:33:48,229 controller 2672 -- Replica(id='8hv13gvb', deployment='ActionDetectorClass', app='default') is stopped.
# (ServeController pid=2672) INFO 2025-08-04 22:33:48,236 controller 2672 -- Replica(id='xbgrp3bi', deployment='RepCounterClass', app='default') is stopped.
# (ServeController pid=2672) INFO 2025-08-04 22:33:48,245 controller 2672 -- Replica(id='1uhu3hy6', deployment='Ingress', app='default') is stopped.
# (ServeReplica:default:RepCounterClass pid=2676) /workspaces/visionmlstudio/serve/
# (ServeReplica:default:RepCounterClass pid=2676) Using cache found in /home/jovyan/.cache/torch/hub/huggingface_pytorch-image-models_main
# (ServeController pid=2672) WARNING 2025-08-04 22:34:15,023 controller 2672 -- Deployment 'ActionDetectorClass' in application 'default' has 1 replicas that have taken more than 30s to be scheduled. This may be due to waiting for the cluster to auto-scale or for a runtime environment to be installed. Resources required for each replica: {"CPU": 1}, total resources available: {"CPU": 13.0}. Use `ray status` for more details.
# (ProxyActor pid=2675) INFO 2025-08-04 22:37:06,495 proxy 172.17.0.2 a2789ec4-ca33-4fc1-b725-b384deeb4b31 -- Client for request a2789ec4-ca33-4fc1-b725-b384deeb4b31 disconnected, cancelling request.
# (ProxyActor pid=2675) ERROR:    ASGI callable returned without sending handshake.
# (ServeReplica:default:Ingress pid=2682) INFO 2025-08-04 22:37:06,503 default_Ingress ach4ksv7 a2789ec4-ca33-4fc1-b725-b384deeb4b31 -- WS /ws CANCELLED 9784.5ms
# (ProxyActor pid=2675) Task exception was never retrieved
# (ProxyActor pid=2675) future: <Task finished name='Task-2380' coro=<WebSocketProtocol.run_asgi() done, defined at /opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py:238> exception=RuntimeError('unable to perform operation on <TCPTransport closed=True reading=False 0x7f7974132c50>; the handler is closed')>
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 260, in run_asgi
# (ProxyActor pid=2675)     self.send_500_response()
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 224, in send_500_response
# (ProxyActor pid=2675)     self.transport.write(b"".join(content))
# (ProxyActor pid=2675)   File "uvloop/handles/stream.pyx", line 678, in uvloop.loop.UVStream.write
# (ProxyActor pid=2675)   File "uvloop/handles/handle.pyx", line 159, in uvloop.loop.UVHandle._ensure_alive
# (ProxyActor pid=2675) RuntimeError: unable to perform operation on <TCPTransport closed=True reading=False 0x7f7974132c50>; the handler is closed
# (ServeReplica:default:Ingress pid=2682) INFO 2025-08-04 22:37:12,717 default_Ingress ach4ksv7 3332da35-6312-457f-9d16-6b005168d6e4 -- Started <ray.serve._private.router.SharedRouterLongPollClient object at 0x7f34a009cdd0>.
# (ServeReplica:default:ActionDetectorClass pid=2678) /opt/conda/lib/python3.12/site-packages/ray/serve/_private/replica.py:1365: UserWarning: Calling sync method '__call__' directly on the asyncio loop. In a future version, sync methods will be run in a threadpool by default. Ensure your sync methods are thread safe or keep the existing behavior by making them `async def`. Opt into the new behavior by setting RAY_SERVE_RUN_SYNC_IN_THREADPOOL=1.
# (ServeReplica:default:ActionDetectorClass pid=2678)   warnings.warn(
# (ServeReplica:default:ActionDetectorClass pid=2678) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 0 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 1 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 2 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 3 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 4 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 5 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 6 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 7 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Processing 8 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2678) INFO 2025-08-04 22:37:58,368 default_ActionDetectorClass 7lbkp4f3 3332da35-6312-457f-9d16-6b005168d6e4 -- CALL /ws OK 45305.8ms
# (ServeReplica:default:Ingress pid=2682) INFO 2025-08-04 22:37:58,408 default_Ingress ach4ksv7 3332da35-6312-457f-9d16-6b005168d6e4 -- WS /ws OK 70136.2ms
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.send', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2682) WebSocket error: (1000, '')
# (ServeReplica:default:ActionDetectorClass pid=2678) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 0 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 1 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 2 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 3 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 4 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 5 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 6 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Selected frame 7 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2678) Processing 8 frames for action detection
# (ProxyActor pid=2675) INFO 2025-08-04 22:45:51,128 proxy 172.17.0.2 c025a2f5-8a47-4f80-9a70-89792d504fc3 -- Client for request c025a2f5-8a47-4f80-9a70-89792d504fc3 disconnected, cancelling request.
# (ProxyActor pid=2675) ERROR:    ASGI callable returned without sending handshake.
# (ProxyActor pid=2675) Task exception was never retrieved
# (ProxyActor pid=2675) future: <Task finished name='Task-2514' coro=<WebSocketProtocol.run_asgi() done, defined at /opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py:238> exception=RuntimeError('unable to perform operation on <TCPTransport closed=True reading=False 0x7f79741df740>; the handler is closed')>
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 260, in run_asgi
# (ProxyActor pid=2675)     self.send_500_response()
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 224, in send_500_response
# (ProxyActor pid=2675)     self.transport.write(b"".join(content))
# (ProxyActor pid=2675)   File "uvloop/handles/stream.pyx", line 678, in uvloop.loop.UVStream.write
# (ProxyActor pid=2675)   File "uvloop/handles/handle.pyx", line 159, in uvloop.loop.UVHandle._ensure_alive
# (ProxyActor pid=2675) RuntimeError: unable to perform operation on <TCPTransport closed=True reading=False 0x7f79741df740>; the handler is closed
# (ServeReplica:default:ActionDetectorClass pid=2678) INFO 2025-08-04 22:45:57,949 default_ActionDetectorClass 7lbkp4f3 175cbdd2-7bf4-4a1d-b5e2-2f99234a9c87 -- CALL /ws OK 46302.7ms
# (ServeReplica:default:Ingress pid=2682) INFO 2025-08-04 22:45:57,966 default_Ingress ach4ksv7 175cbdd2-7bf4-4a1d-b5e2-2f99234a9c87 -- WS /ws OK 47350.0ms
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# ...
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2683) INFO 2025-08-04 23:25:23,254 default_Ingress jnuui0dw c7f70e29-7b29-481e-9244-9aa518f1c76f -- WS /ws OK 418.7ms
# (ServeReplica:default:Ingress pid=2683) WebSocket error: (1000, '')
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2683) INFO 2025-08-04 23:25:39,116 default_Ingress jnuui0dw d406cd8d-0bae-49d4-8ede-958aebabce01 -- WS /ws OK 422.0ms
# (ServeReplica:default:Ingress pid=2683) WebSocket error: (1000, '')
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=2683) INFO 2025-08-04 23:28:33,137 default_Ingress jnuui0dw 661e03f1-eaf7-4fc6-9cd2-d8cc8e84284f -- WS /ws OK 243.2ms
# (ServeReplica:default:Ingress pid=2683) WebSocket error: (1000, '')
# (ServeController pid=2672) INFO 2025-08-04 23:38:07,031 controller 2672 -- Deploying new version of Deployment(name='ActionDetectorClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 23:38:07,034 controller 2672 -- Deploying new version of Deployment(name='RepCounterClass', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 23:38:07,035 controller 2672 -- Deploying new version of Deployment(name='Ingress', app='default') (initial target replicas: 1).
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,661 controller 2672 -- Stopping 1 replicas of Deployment(name='ActionDetectorClass', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,661 controller 2672 -- Adding 1 replica to Deployment(name='ActionDetectorClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,673 controller 2672 -- Stopping 1 replicas of Deployment(name='RepCounterClass', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,674 controller 2672 -- Adding 1 replica to Deployment(name='RepCounterClass', app='default').
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,703 controller 2672 -- Stopping 1 replicas of Deployment(name='Ingress', app='default') with outdated versions.
# (ServeController pid=2672) INFO 2025-08-04 23:38:12,703 controller 2672 -- Adding 1 replica to Deployment(name='Ingress', app='default').
# (ServeController pid=2672) INFO 2025-08-04 23:38:22,540 controller 2672 -- Replica(id='yfv07lun', deployment='ActionDetectorClass', app='default') is stopped.
# (ServeController pid=2672) INFO 2025-08-04 23:38:22,544 controller 2672 -- Replica(id='gu7rzvk9', deployment='RepCounterClass', app='default') is stopped.
# (ServeController pid=2672) INFO 2025-08-04 23:38:22,550 controller 2672 -- Replica(id='jnuui0dw', deployment='Ingress', app='default') is stopped.
# (ServeReplica:default:RepCounterClass pid=2684) /workspaces/visionmlstudio/serve/
# (ServeReplica:default:RepCounterClass pid=2684) Using cache found in /home/jovyan/.cache/torch/hub/huggingface_pytorch-image-models_main
# (ServeController pid=2672) WARNING 2025-08-04 23:38:57,132 controller 2672 -- Deployment 'ActionDetectorClass' in application 'default' has 1 replicas that have taken more than 30s to be scheduled. This may be due to waiting for the cluster to auto-scale or for a runtime environment to be installed. Resources required for each replica: {"CPU": 1}, total resources available: {"CPU": 13.0}. Use `ray status` for more details.
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.close', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:Ingress pid=60034) INFO 2025-08-04 23:41:59,322 default_Ingress ykpxq3mk 122633d9-7d49-4d3b-9d2e-c2f7de9b2561 -- WS /ws OK 1012.7ms
# (ServeReplica:default:Ingress pid=60034) WebSocket error: (1000, '')
# (ServeReplica:default:Ingress pid=60034) Received data of length 4817024
# (ServeReplica:default:Ingress pid=60034) Batch shape: (32, 224, 224, 3), dtype: uint8
# (ServeReplica:default:Ingress pid=60034) INFO 2025-08-04 23:54:18,983 default_Ingress ykpxq3mk 3b32acdc-8c69-4a01-9e27-b92d7d586d11 -- Started <ray.serve._private.router.SharedRouterLongPollClient object at 0x7fb0e2148bf0>.
# (ServeReplica:default:ActionDetectorClass pid=2677) /opt/conda/lib/python3.12/site-packages/ray/serve/_private/replica.py:1365: UserWarning: Calling sync method '__call__' directly on the asyncio loop. In a future version, sync methods will be run in a threadpool by default. Ensure your sync methods are thread safe or keep the existing behavior by making them `async def`. Opt into the new behavior by setting RAY_SERVE_RUN_SYNC_IN_THREADPOOL=1.
# (ServeReplica:default:ActionDetectorClass pid=2677)   warnings.warn(
# (ServeReplica:default:ActionDetectorClass pid=2677) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 0 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 1 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 2 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 3 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 4 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 5 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 6 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 7 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Processing 8 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2677) INFO 2025-08-04 23:54:40,721 default_ActionDetectorClass 6xi7fyoq 3b32acdc-8c69-4a01-9e27-b92d7d586d11 -- CALL /ws OK 21644.9ms
# (ServeReplica:default:ActionDetectorClass pid=2677) Predicted class: 3
# (ServeReplica:default:Ingress pid=60034) Action detection result: {'action': 'class_3'}
# (ServeReplica:default:Ingress pid=60034) Received data of length 4817024
# (ServeReplica:default:Ingress pid=60034) Batch shape: (32, 224, 224, 3), dtype: uint8
# (ServeReplica:default:ActionDetectorClass pid=2677) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 0 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 1 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 2 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 3 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 4 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 5 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 6 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 7 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Processing 8 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2677) INFO 2025-08-04 23:55:10,344 default_ActionDetectorClass 6xi7fyoq 3b32acdc-8c69-4a01-9e27-b92d7d586d11 -- CALL /ws OK 26962.2ms
# (ServeReplica:default:ActionDetectorClass pid=2677) Predicted class: 3
# (ServeReplica:default:Ingress pid=60034) Action detection result: {'action': 'class_3'}
# (ServeReplica:default:ActionDetectorClass pid=2677) Received 32 frames for action detection
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 0 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 1 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 2 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 3 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 4 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 5 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 6 with shape (224, 224, 3)
# (ServeReplica:default:ActionDetectorClass pid=2677) Selected frame 7 with shape (224, 224, 3)
# (ServeReplica:default:Ingress pid=60034) Received data of length 4817024
# (ServeReplica:default:Ingress pid=60034) Batch shape: (32, 224, 224, 3), dtype: uint8
# (ServeReplica:default:ActionDetectorClass pid=2677) Processing 8 frames for action detection
# (ProxyActor pid=2675) ERROR:    Exception in ASGI application
# (ProxyActor pid=2675) Traceback (most recent call last):
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
# (ProxyActor pid=2675)     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
# (ProxyActor pid=2675)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
# (ProxyActor pid=2675)     return await self.app(scope, receive, send)
# (ProxyActor pid=2675)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 577, in __call__
# (ProxyActor pid=2675)     await self._app(scope, receive, send_with_request_id)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/proxy.py", line 852, in __call__
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/ray/serve/_private/http_util.py", line 575, in send_with_request_id
# (ProxyActor pid=2675)     await send(message)
# (ProxyActor pid=2675)   File "/opt/conda/lib/python3.12/site-packages/uvicorn/protocols/websockets/websockets_impl.py", line 360, in asgi_send
# (ProxyActor pid=2675)     raise RuntimeError(msg % message_type)
# (ProxyActor pid=2675) RuntimeError: Unexpected ASGI message 'websocket.send', after sending 'websocket.close' or response already completed.
# (ServeReplica:default:ActionDetectorClass pid=2677) INFO 2025-08-04 23:55:38,211 default_ActionDetectorClass 6xi7fyoq 3b32acdc-8c69-4a01-9e27-b92d7d586d11 -- CALL /ws OK 23997.6ms
# (ServeReplica:default:Ingress pid=60034) INFO 2025-08-04 23:55:38,251 default_Ingress ykpxq3mk 3b32acdc-8c69-4a01-9e27-b92d7d586d11 -- WS /ws OK 87694.5ms
# (ServeReplica:default:ActionDetectorClass pid=2677) Predicted class: 3
# (ServeReplica:default:Ingress pid=60034) Action detection result: {'action': 'class_3'}
# (ServeReplica:default:Ingress pid=60034) WebSocket error: (<CloseCode.ABNORMAL_CLOSURE: 1006>, '')

# %%
run ./serve/actiondetection_timesformer.py
# Out:
# 2025-08-04 23:37:40,527	INFO worker.py:1723 -- Connecting to existing Ray cluster at address: 172.17.0.2:64913...
# 2025-08-04 23:37:40,531	INFO worker.py:1747 -- Calling ray.init() again after it has already been called.
# INFO 2025-08-04 23:37:40,759 serve 1757 -- Connecting to existing Serve app in namespace "serve". New http options will not be applied.
# INFO 2025-08-04 23:37:47,796 serve 1757 -- Connecting to existing Serve app in namespace "serve". New http options will not be applied.
# INFO 2025-08-04 23:39:29,117 serve 1757 -- Application 'default' is ready at http://127.0.0.1:8000/.
